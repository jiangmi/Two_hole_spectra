# %%
# %pylab inline

import math
import numpy as np
from scipy.sparse.linalg import inv
#from numpy.linalg import inv
import scipy.sparse as sps
import scipy.sparse.linalg
from scipy import integrate
import sys
import matplotlib.pyplot as plt
sys.path.append('../../src/')
from pylab import *

import parameters as pam
import lattice as lat
import variational_space as vs
import hamiltonian as ham
import basis_change as basis
import lanczos

M_PI = math.pi
Mc  = pam.Mc
print 'Mc=',Mc

w_vals = pam.w_vals
Norb = pam.Norb
eta = pam.eta
ed  = pam.ed
ep  = pam.ep

if Norb==3 or Norb==7:
    tpd = pam.tpd
    tpp = pam.tpp
elif Norb==9:
    pds = pam.pds
    pdp = pam.pdp
    pps = pam.pps
    ppp = pam.ppp
    
Upp = pam.Upp
if Norb==3:
    Udd = pam.Udd
elif Norb==7 or Norb==9:
    A = pam.A
    B = pam.B
    C = pam.C
                    
if Norb==3:
    fname = 'ep'+str(ep)+'_tpd'+str(tpd)+'_tpp'+str(tpp)+ \
            '_Udd'+str(Udd)+'_Upp'+str(Upp)+'_Mc'+str(Mc)+'_Norb'+str(Norb)
elif Norb==7:
    fname = 'ep'+str(ep)+'_tpd'+str(tpd)+'_tpp'+str(tpp) \
          +'_A'+str(A)+'_B'+str(B)+'_C'+str(C) \
          +'_Upp'+str(Upp)+'_Mc'+str(Mc)+'_Norb'+str(Norb)
elif Norb==9:
    fname = 'ep'+str(ep)+'_pds'+str(pds)+'_pdp'+str(pdp)+'_pps'+str(pps)+'_ppp'+str(ppp) \
          +'_A'+str(A)+'_B'+str(B)+'_C'+str(C) \
          +'_Upp'+str(Upp)+'_Mc'+str(Mc)+'_Norb'+str(Norb)
                        
Ms = ['-b','-r','-g','-m','-c','-k','-y','--b','--r','--g','--m','--c','--k','--y',\
      '-.b','-.r','-.g','-.m','-.c','-.k','-.y',':b',':r',':g',':m',':c',':k',':y']
#####################################
def writefile(fname,state,Aw):
    f = open(fname,'w',1) # line buffering

    # Print header into file
    f.write('#Mc\t{:.6f}\n'.format(Mc))
    f.write('#tpd\t{:.6f}\n'.format(tpd))
    f.write('#tpp\t{:.6f}\n'.format(tpp))
    f.write('#ed\t{:.6f}\n'.format(ed))
    f.write('#ep\t{:.6f}\n'.format(ep))
    f.write('#Upp\t{:.6f}\n'.format(Upp))
    f.write('#eta\t{:.6f}\n'.format(eta))
    f.write('#state_pairs = \t\n')
    f.write(str(state)+'\n')
    f.write('#omega\tspectral weight\n')
    
    for i in xrange(0,len(w_vals)):
        f.write('{:.6e}\t{:.6e}\n'.format(float(w_vals[i]),Aw[i]))
    
def getAw(matrix,index,VS,w_vals):  
    # set up Lanczos solver
    dim  = VS.dim
    scratch = np.empty(dim, dtype = complex)
    Phi0 = np.zeros(dim, dtype = complex)
    Phi0[index] = 1.0
    solver = lanczos.LanczosSolver(maxiter = pam.Lanczos_maxiter, 
                                   precision = 1e-12, 
                                   cond = 'UPTOMAX', 
                                   eps = 1e-8)
    solver.first_pass(x0 = Phi0, scratch = scratch, H = matrix)
    V, D = solver.lanczos_diag_T()

    # D[0,:] is the eigenvector for lowest eigenvalue
    tab = np.abs(D[0,:])**2

    Aw = np.zeros(len(w_vals))
    for n in range(len(V)):
        Aw += tab[n] * eta / M_PI * ( (w_vals - V[n])**2 + eta**2)**(-1)
        
    w_peak, weight = getAw_peak_pos_weight(Aw, D, tab)
    return Aw# w_peak, weight

def getAw_peak_pos_weight(Aw, D, tab):  
    '''
    find the position and weight of lowest peak of Aw
    used to explore their dispersion in the high symmetry points in BZ
    '''    
    w_idx = np.argmax(Aw)
    w_peak = w_vals[w_idx]
    print 'w_lowpeak = ', w_peak
    
    # find the area below the whole peak, namely the peak weight
    # ==========================================================
    # 1. first find the peak's w-range: [w_min, w_max]
    wid = w_idx
    while Aw[wid]>1.e-3:
        #print w_vals[wid], Aw[wid]
        if Aw[wid-1]>Aw[wid]:
            break
        wid -= 1
    w_min = wid
    
    wid = w_idx
    while Aw[wid]>1.e-3:
        #print w_vals[wid], Aw[wid]
        if Aw[wid+1]>Aw[wid]:
            break
        wid += 1
    w_max = wid
    
    print 'peak w-range = [', w_vals[w_min], w_vals[w_max], ']'
    
    # 2. Simpson's rule
    weight = integrate.simps(Aw[w_min:w_max], w_vals[w_min:w_max])
    print 'peak, weight = ', w_peak, '  ', weight
                          
    '''
    # find the eigenvalue D[n] nearest to w_peak so that its index n
    # leads to weight = tab[n]; Note that this weight is actually for 
    # the single peak instead of the area below the whole peak
    tmp = []
    for n in range(len(D)):
        tmp.append(abs(D[n]-w_peak))
        
    idx = tmp.index(min(tmp))
    weight = tab[idx]
    assert(weight>=0.0 and weight<=1.0)
    '''
    return w_peak, weight

def get_ground_state(matrix,S_val,Sz_val):  
    '''
    Obtain the ground state info, namely the lowest peak in Aw_dd's component
    in particular how much weight of various d8 channels: a1^2, b1^2, b2^2, e^2
    
    Note that if Aw has a lowest single peak, then its energy should equal E0
    '''        
    Neval = 20
    vals, vecs = sps.linalg.eigsh(matrix, k=Neval, which='SA')
    print 'lowest eigenvalue of H = ', vals
    
    # get state components in GS and another 9 higher states; note that indices is a tuple
    for k in xrange(0,Neval):
        print 'eigenvalue = ', vals[k]
        indices = np.nonzero(abs(vecs[:,k])>0.05)

        print "Compute the weights in GS (lowest Aw peak)"
        for i in indices[0]:
            # now the basis is after basis change, namely singlets/triplets
            # but its orbital info remains the same as original states
            state = VS.get_state(VS.lookup_tbl[i])
            s1 = state['hole1_spin']
            s2 = state['hole2_spin']
            o1 = state['hole1_orb']
            o2 = state['hole2_orb']
            x1, y1 = state['hole1_coord']
            x2, y2 = state['hole2_coord']

            # also obtain the total S and Sz of the state
            S12  = S_val[i]
            Sz12 = Sz_val[i]

            print 'state ', o1,x1,y1,o2,x2,y2, 'S=',S12,'Sz=',Sz12, \
                  ", weight = ", abs(vecs[i,k])**2
    return vals, vecs

def plot_atomic_multiplet_peaks(data_for_maxval):
    maxval = max(data_for_maxval)
    yy = [0,maxval]
    xx = [pam.E_1S,pam.E_1S]
    plt.plot(xx, yy,'--k', linewidth=0.5)
    #text(pam.E_1S-0.2, 10.2, 'E_1S', fontsize=5)
    xx = [pam.E_1G,pam.E_1G]
    plt.plot(xx, yy,'--k', linewidth=0.5)
    #text(pam.E_1G-0.2, 10.5, 'E_1G', fontsize=5)
    xx = [pam.E_1D,pam.E_1D]
    plt.plot(xx, yy,'--k', linewidth=0.5)
    #text(pam.E_1D-0.2, 10.8, 'E_1D', fontsize=5)
    xx = [pam.E_3P,pam.E_3P]
    plt.plot(xx, yy,'--k', linewidth=0.5)
    #text(pam.E_3P-0.2, 11.1, 'E_3P', fontsize=5)
    xx = [pam.E_3F,pam.E_3F]
    plt.plot(xx, yy,'--k', linewidth=0.5)
    #text(pam.E_3F-0.2, 11.4, 'E_3F', fontsize=5)
            
def compute_Aw(pam_flag,ham_func,fig_name):
    if pam_flag == 1:
        state_indices = ham_func(VS)
        print "===================================="
        clf()
        Nstate = len(state_indices)
        for j in range(0,Nstate):
            index = state_indices[j]
            Aw = getAw(H,index,VS,w_vals)           

            state = VS.get_state(VS.lookup_tbl[index])
            s1 = state['hole1_spin']
            s2 = state['hole2_spin']
            o1 = state['hole1_orb']
            o2 = state['hole2_orb']
            #subplot(Nstate,1,j+1)
            plt.plot(w_vals, Aw, Ms[j], linewidth=1, label=tuple([s1,o1,s2,o2]))

            maxval = max(Aw)
            #xlim([-5,20])
            xlim([0,15])
            #ylim([0,maxval])
            ylim([0,0.5])
            #ylabel('$A(\omega)$',fontsize=14)
            #text(0.45, 0.1, '(a)', fontsize=16)
            grid('on',linestyle="--", linewidth=0.5, color='black', alpha=0.5)
            legend(loc='best', fontsize=6.5, framealpha=1.0, edgecolor='black')
            if j==0:
                title(fname, fontsize=8)
            if j==Nstate-1:
                xlabel('$\omega$',fontsize=15)

        savefig(fig_name+fname+".pdf")

if __name__ == '__main__':    
    # set up H0
    VS = vs.VariationalSpace(Mc)
    basis.count_VS(VS)
    T_pd  = ham.create_tpd_nn_matrix(VS)
    T_pp  = ham.create_tpp_nn_matrix(VS)       
    Esite = ham.create_edep_diag_matrix(VS)
    
    # Note there is no tpp prefactor that is considered in hamiltonian.py
    H0 = T_pd + T_pp + ep*Esite
    
    # check_hermitian for H0
    #H0_max = H0.todense()
    #if ham.check_hermitian(H0_max):
    #    print 'hermitian'
        
    # set up H_int
    # for multi d-orbital cases, compute A(w) for each symmetry channel
    Aw = np.zeros(len(w_vals))
    Aw_dd_total = np.zeros(len(w_vals))
    Aw_d8_total = np.zeros(len(w_vals))
    
    d_double, p_double = ham.get_double_occu_list(VS)
    
    # change the basis for d_double states to be singlet/triplet
    #U, S_val, Sz_val = basis.create_singlet_triplet_basis_change_matrix_d_double(VS,d_double)
    U, S_val, Sz_val = basis.create_singlet_triplet_basis_change_matrix(VS)
    U_d = (U.conjugate()).transpose()
    H0_new = U_d.dot(H0.dot(U))

    # check if U if unitary
    #UdU = U_d.dot(U)
    #sh = UdU.shape
    #print sh
    #bb = sps.identity(sh[0], format='coo')
    #tmp = UdU-bb
    #print 'U_d.dot(U)-I = ', tmp
    
    #======================= start opt for Norb=3 or 7, 9 ======================================
    if Norb==3:
        Hint, Aw_state_indices = ham.create_interaction_matrix_Norb3(VS,d_double,p_double)
        H = H0_new + Hint
        H.tocsr()
        
        if pam.if_get_ground_state==1:
            S_val  = np.zeros(VS.dim, dtype=int)
            Sz_val = np.zeros(VS.dim, dtype=int)
            vals, vecs = get_ground_state(H, S_val, Sz_val)
                
        # For debug: check if H is hermitian: only practical for small Mc, namely small matrix
        #out_mat = H.todense()
        #assert(ham.check_hermitian(out_mat)==True)
        
        Nstate = len(Aw_state_indices)
        for j in range(0,Nstate):
            index = Aw_state_indices[j]
            Aw = getAw(H,index,VS,w_vals)      

            state = VS.get_state(VS.lookup_tbl[index])
            s1 = state['hole1_spin']
            s2 = state['hole2_spin']
            o1 = state['hole1_orb']
            o2 = state['hole2_orb']
            #subplot(Nstate,1,j+1)
            plt.plot(w_vals, Aw, Ms[j], linewidth=1, label=tuple([s1,o1,s2,o2]))

            maxval = max(Aw)
            #xlim([-6.5,12])
            #ylim([0,maxval])
            ylim([0,0.5])
            #ylabel('$A(\omega)$',fontsize=14)
            #text(0.45, 0.1, '(a)', fontsize=16)
            grid('on',linestyle="--", linewidth=0.5, color='black', alpha=0.5)
            legend(loc='best', fontsize=6.5, framealpha=1.0, edgecolor='black')
            if j==0:
                title(fname, fontsize=8)
            if j==Nstate-1:
                xlabel('$\omega$',fontsize=15)

        savefig("Aw_"+fname+".pdf")

        # plot Matlab data for comparison
        #a = np.loadtxt('../data/dataMatlab.txt',skiprows=1)
        #la = len(a)
        #print la
        #plt.plot(a[0:la/3-1,0], a[0:la/3-1,1], '--c', linewidth=1, label='dd, Matlab')
        #plt.plot(a[la/3:2*la/3-1,0], a[la/3:2*la/3-1,1], '--m', linewidth=1, label='dp, Matlab')
        #plt.plot(a[2*la/3:la-1,0], a[2*la/3:la-1,1], '--k', linewidth=1, label='pp, Matlab')

    elif Norb==7 or Norb==9:
        Nsym = len(pam.symmetries)
        for i in range(0,Nsym):
            sym = pam.symmetries[i]
            print "===================================="
            print "start computing A_dd(w) for sym", sym
            Hint, dd_state_indices = ham.create_interaction_matrix(VS,sym,d_double,p_double,S_val, Sz_val)
            H = H0_new + Hint  
            H.tocsr()
            
            #dd_states, d8_states, coef_frac_parentage = ham.get_Aw_state(sym)

            if pam.if_get_ground_state==1:
                vals, vecs = get_ground_state(H, S_val, Sz_val)
            
            # compute G_dd(sym)
            Aw_dGS = np.zeros(len(w_vals))
            Aw_dd  = np.zeros(len(w_vals))
            Aw_d8  = np.zeros(len(w_vals))
        
            for index in dd_state_indices:
                Aw_tmp  = getAw(H,index,VS,w_vals)
                Aw_dd  += Aw_tmp  #*coef_frac_parentage[spinorb]
                #Aw_dGS += Aw_tmp
                
            # compute G_d_GS(sym) as in Eq.(13) in Eskes's PRB 1990 paper
            #Cu_dx2y2_O_indices = ham.get_Cu_dx2y2_O_indices(VS)
            #for ind in Cu_dx2y2_O_indices:
            #    Aw_tmp = getAw(H,ind,VS,w_vals)
            #    Aw_dGS += Aw_tmp  #*coef_frac_parentage[spinorb]
    
            # accumulate Aw for each sym into total Aw_dd
            Aw_dd_total += Aw_dd
              
            subplot(Nsym,1,i+1)
            plt.plot(w_vals, Aw_dd, Ms[i], linewidth=1, label=sym)
            
            # plot atomic multiplet peaks
            #plot_atomic_multiplet_peaks(Aw_dd)
                
            if i==0:
                title(fname, fontsize=8)
            if i==Nsym-1:
                xlabel('$\omega$',fontsize=15)
                
            #xlim([-5,20])
            #xlim([-7.5,13])
            #ylim([0,0.3])
            #ylim([0,maxval])
            #ylabel('$A(\omega)$',fontsize=17)
            #text(0.45, 0.1, '(a)', fontsize=16)
            #grid('on',linestyle="--", linewidth=0.5, color='black', alpha=0.5)
            legend(loc='best', fontsize=9.5, framealpha=1.0, edgecolor='black')
            #yticks(fontsize=12)   
            
        savefig("Aw_dd_"+fname+"_sym.pdf")
        ############################################################
        # plot total Gdd
        if pam.if_compute_Aw_dd_total == 1:
            clf()
            plt.plot(w_vals, Aw_dd_total,'-b', linewidth=1)
            title(fname, fontsize=8)
            maxval = max(Aw_dd_total)
            xlim([-5,0])
            ylim([0,maxval])
            xlabel('$\omega$',fontsize=17)
            ylabel('$A(\omega)$',fontsize=17)
            #text(0.45, 0.1, '(a)', fontsize=16)
            #grid('on',linestyle="--", linewidth=0.5, color='black', alpha=0.5)
            legend(loc='best', fontsize=9.5, framealpha=1.0, edgecolor='black')

            # plot atomic multiplet peaks
            plot_atomic_multiplet_peaks(Aw_dd_total)

            savefig("Aw_dd_"+fname+"_total.pdf")
    ############################################################
    # compute G_pp and plot
    compute_Aw(pam.if_compute_Aw_pp, ham.get_pp_state_indices, "Aw_pp_")

    # compute G_dp and plot
    compute_Aw(pam.if_compute_Aw_dp, ham.get_dp_state_indices, "Aw_dp_")
    
    # compute G_Cu_dx2y2_O and plot
    compute_Aw(pam.if_compute_Aw_Cu_dx2y2_O, ham.get_Cu_dx2y2_O_indices, "Aw_Cu_dx2y2_O_")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Cu_orbs =  ['d3z2r2', 'dx2y2', 'dxy', 'dxz', 'dyz']
# O1_orbs =  ['px']
# O2_orbs =  ['py']
# symmetries =  ['1A1', '1B1', '3B1']
# E_1S =  12.66
# E_1G =  8.26
# E_1D =  7.21
# E_3P =  7.55
# E_3F =  5.3
# Mc= 20
# VS.dim =  327645
# No. of states with count_upup, count_updn, count_dnup, count_dndn: 81810 82225 81800 81810
# start create_tpd_nn_matrix
# ==========================
# start create_tpp_nn_matrix
# ==========================
# start create_edep_diag_matrix
# =============================
# len(d_list) 45 Nd= 45
# ====================================
# start computing A_dd(w) for sym 1A1
# orbitals in sym  1A1 =  [('dyz', 'dyz'), ('dxz', 'dxz'), ('dxy', 'dxy'), ('d3z2r2', 'd3z2r2'), ('dx2y2', 'dx2y2')]
# dd_state_indices 83808 , state: S=  0  Sz=  1 orb=  dx2y2 dx2y2
# lowest eigenvalue of H =  [-2.19466319 -2.19466319 -2.19466319 -2.19466319 -1.74250366 -1.74250366
#  -1.74250366 -1.74250366 -1.74250366 -1.74250366 -1.74250366 -1.74250366
#  -1.74250366 -1.74250366 -1.74250366 -1.74250366 -1.6847513  -0.59874421
#  -0.59874421 -0.59874421]
# eigenvalue =  -2.1946631914931203
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 0 , weight =  0.01312494556285153
# state  px -1 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.047856762676691825
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 1 , weight =  0.005705960925540608
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.003260816082270853
# state  px -1 0 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.002651274856314525
# state  px -1 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.009667196788110517
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 0 , weight =  0.01312494556285152
# state  py 0 -1 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.047856762676691866
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 1 , weight =  0.005705960925540604
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.00326081608227085
# state  py 0 -1 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.002651274856314525
# state  py 0 -1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.00966719678811065
# state  dx2y2 0 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.4261893641003102
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.1168844671143463
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.05081454997000385
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.029039263310385335
# state  py 0 -1 py 0 1 S= 0 Sz= 1 , weight =  0.004342114387712382
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.013124945562851527
# state  d3z2r2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.047856762676691804
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.005705960925540604
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.00326081608227085
# state  dx2y2 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.002651274856314523
# state  dx2y2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.009667196788110642
# state  px -1 0 px 1 0 S= 0 Sz= 1 , weight =  0.004342114387712343
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.013124945562851527
# state  d3z2r2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.04785676267669177
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.005705960925540608
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.00326081608227085
# state  dx2y2 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.0026512748563145227
# state  dx2y2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.009667196788110512
# eigenvalue =  -2.1946631914931163
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 py 0 -1 S= 1 Sz= 0 , weight =  0.005032016283852425
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 0 , weight =  0.05546054009149397
# state  px -1 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.009058992726065536
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.004468182880110072
# state  px -1 0 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.011203180596678644
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 0 , weight =  0.05546054009149401
# state  py 0 -1 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.009058992726065522
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.004468182880110074
# state  py 0 -1 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.011203180596678616
# state  dx2y2 0 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.08067504221700324
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.49390495704728377
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.008556152579591324
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.039791492651162275
# state  px -1 0 py 0 1 S= 1 Sz= 0 , weight =  0.005032016283852429
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.05546054009149393
# state  d3z2r2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.009058992726065541
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.004468182880110066
# state  dx2y2 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.011203180596678616
# state  py 0 -1 px 1 0 S= 1 Sz= 0 , weight =  0.005032016283852425
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.05546054009149393
# state  d3z2r2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.009058992726065532
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.004468182880110066
# state  dx2y2 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.011203180596678625
# state  py 0 1 px 1 0 S= 1 Sz= 0 , weight =  0.005032016283852427
# eigenvalue =  -2.194663191493109
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 py 0 -1 S= 1 Sz= 1 , weight =  0.0026617182909193845
# state  px -1 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.013032549831888613
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 1 , weight =  0.029336219451337197
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.027046796144774267
# state  px -1 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002632610666268241
# state  px -1 0 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.00592599646514322
# state  px -1 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.005463526703338583
# state  py 0 -1 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.013032549831888635
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 1 , weight =  0.029336219451337218
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.027046796144774277
# state  py 0 -1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0026326106662681588
# state  py 0 -1 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.005925996465143233
# state  py 0 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0054635267033385955
# state  dx2y2 0 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.11606163507092786
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.004745928187022028
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.2612542933072642
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.24086578792982563
# state  px -1 0 py 0 1 S= 1 Sz= 1 , weight =  0.002661718290919386
# state  d3z2r2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.013032549831888635
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.029336219451337218
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.027046796144774295
# state  dx2y2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0026326106662681644
# state  dx2y2 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.0059259964651432115
# state  dx2y2 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.005463526703338579
# state  py 0 -1 px 1 0 S= 1 Sz= 1 , weight =  0.002661718290919386
# state  d3z2r2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.01303254983188861
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.029336219451337197
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.027046796144774277
# state  dx2y2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.002632610666268233
# state  dx2y2 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.0059259964651432115
# state  dx2y2 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.005463526703338585
# state  py 0 1 px 1 0 S= 1 Sz= 1 , weight =  0.0026617182909193845
# eigenvalue =  -2.194663191493105
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 py 0 -1 S= 1 Sz= 1 , weight =  0.0030799282916559785
# state  px -1 0 py 0 -1 S= 1 Sz= 2 , weight =  0.0031912698513284292
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 1 , weight =  0.033945535320791996
# state  px -1 0 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.03517269014019879
# state  px -1 0 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.006857090861761934
# state  px -1 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.007104979487426601
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 1 , weight =  0.03394553532079198
# state  py 0 -1 d3z2r2 0 0 S= 1 Sz= 2 , weight =  0.03517269014019886
# state  py 0 -1 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.006857090861761952
# state  py 0 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.007104979487426606
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 0 , weight =  0.0073922921463890606
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 1 , weight =  0.3023026486381837
# state  d3z2r2 0 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.31323110060366455
# state  px -1 0 py 0 1 S= 1 Sz= 1 , weight =  0.003079928291655969
# state  px -1 0 py 0 1 S= 1 Sz= 2 , weight =  0.0031912698513284305
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.033945535320791996
# state  d3z2r2 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.03517269014019882
# state  dx2y2 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.0068570908617619246
# state  dx2y2 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.007104979487426617
# state  py 0 -1 px 1 0 S= 1 Sz= 1 , weight =  0.0030799282916559785
# state  py 0 -1 px 1 0 S= 1 Sz= 2 , weight =  0.0031912698513284323
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.033945535320791996
# state  d3z2r2 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.03517269014019885
# state  dx2y2 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.006857090861761938
# state  dx2y2 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.0071049794874266225
# state  py 0 1 px 1 0 S= 1 Sz= 1 , weight =  0.0030799282916559715
# state  py 0 1 px 1 0 S= 1 Sz= 2 , weight =  0.0031912698513284275
# eigenvalue =  -1.7425036578339337
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.012333578331847013
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.015719667813545314
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.00462159545061108
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.006398283207662756
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.004724681435963564
# state  px -1 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.00844321919511193
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.014665150363372478
# state  px -1 0 dyz 0 0 S= 0 Sz= 1 , weight =  0.0032747084172319724
# state  px -1 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.00304695237277849
# state  py 0 -1 dxy 0 0 S= 1 Sz= 0 , weight =  0.012333578331847004
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.015719667813545293
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.004621595450611073
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.006398283207662745
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.004724681435963568
# state  py 0 -1 dxz 0 0 S= 1 Sz= 1 , weight =  0.00844321919511192
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.014665150363372507
# state  py 0 -1 dyz 0 0 S= 0 Sz= 1 , weight =  0.0032747084172319724
# state  py 0 -1 dyz 0 0 S= 1 Sz= 2 , weight =  0.003046952372778493
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.00470266911366032
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.042075745707524786
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.029162981779245135
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.10983693029640149
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.13999181838904248
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.04115771138828268
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.05698004000039846
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.07519125863222755
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.019116444061181622
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.1306007919930875
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.0059117734454577605
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.02713469573717855
# state  dxy 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.012333578331847016
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.015719667813545314
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.0046215954506110745
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.006398283207662758
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.004724681435963568
# state  dxz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.008443219195111915
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.014665150363372525
# state  dyz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.00327470841723197
# state  dyz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.003046952372778493
# state  dxy 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.01233357833184702
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.015719667813545293
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.004621595450611076
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.006398283207662751
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.004724681435963562
# state  dxz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.00844321919511193
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.014665150363372518
# state  dyz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.0032747084172319732
# state  dyz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.00304695237277849
# eigenvalue =  -1.7425036578339295
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.005964055329001653
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.003868483026652236
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.023176437066212408
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.006766347825822286
# state  px -1 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.03435805272901625
# state  py 0 -1 dxy 0 0 S= 1 Sz= 0 , weight =  0.005964055329001682
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.0038684830266522497
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.023176437066212436
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.006766347825822277
# state  py 0 -1 dyz 0 0 S= 1 Sz= 2 , weight =  0.03435805272901626
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.034450853525132996
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0076562415810130765
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.053113014879384024
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.0062268759870731825
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.20639822718661788
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.005945494323843911
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.06025784687214568
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.30597633072736186
# state  dxy 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.005964055329001678
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.003868483026652246
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.023176437066212408
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.006766347825822277
# state  dyz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.03435805272901628
# state  dxy 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.005964055329001666
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.003868483026652241
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.023176437066212332
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.006766347825822291
# state  dyz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.03435805272901625
# eigenvalue =  -1.742503657833928
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.019020572814409806
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.0052572313697662075
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.004554060895995127
# state  px -1 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.025031661439912953
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.0033857083409104577
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.003368646919865705
# state  px -1 0 dyz 0 0 S= 0 Sz= 1 , weight =  0.010576553821689207
# state  py 0 -1 dxy 0 0 S= 1 Sz= 0 , weight =  0.01902057281440979
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.005257231369766211
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.00455406089599513
# state  py 0 -1 dxz 0 0 S= 1 Sz= 1 , weight =  0.025031661439912936
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.0033857083409104577
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.0033686469198656982
# state  py 0 -1 dyz 0 0 S= 0 Sz= 1 , weight =  0.010576553821689209
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.046818379871317754
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.008050879078901202
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.09418971312561882
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.16938809437156294
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.012504603264523594
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.04055628105165469
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.015585405117519295
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.22291996522043486
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.030151493835677223
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.029999553006857752
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.011696406211656225
# state  dxy 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.01902057281440979
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0052572313697662075
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.00455406089599513
# state  dxz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.025031661439912936
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.003385708340910461
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.0033686469198656974
# state  dyz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.010576553821689212
# state  dxy 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.019020572814409813
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.0052572313697662075
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.00455406089599513
# state  dxz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.025031661439912936
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.003385708340910452
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.0033686469198657013
# state  dyz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.010576553821689203
# eigenvalue =  -1.742503657833928
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.010411253008972717
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.004419162951607123
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.0025418573627230463
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.045479879280633406
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.004773219853461863
# state  px -1 0 dyz 0 0 S= 0 Sz= 1 , weight =  0.0040238750006168205
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.010411253008972722
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.004419162951607114
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.002541857362723043
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.045479879280633476
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.004773219853461867
# state  py 0 -1 dyz 0 0 S= 0 Sz= 1 , weight =  0.004023875000616819
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.09271762340795764
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.4050219811339715
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.03583469987967355
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.0030262006757565433
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.039354944690364074
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.02263656194990061
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.0056404974801543386
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.04250800556237101
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.01021412509225748
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.00951412296466858
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.013681957186088224
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.010411253008972728
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.004419162951607125
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.0025418573627230484
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.045479879280633476
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.004773219853461863
# state  dyz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.004023875000616819
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.010411253008972717
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.004419162951607125
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.002541857362723047
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.04547987928063346
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.004773219853461867
# state  dyz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.0040238750006168136
# eigenvalue =  -1.7425036578339272
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.008576558151026306
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.004543928845233488
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.01667859868561038
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.01603317571528887
# state  px -1 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.004372842605291766
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.004548987045935468
# state  px -1 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.01729899306056909
# state  py 0 -1 dxy 0 0 S= 1 Sz= 0 , weight =  0.008576558151026321
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.004543928845233482
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.01667859868561046
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.016033175715288863
# state  py 0 -1 dxz 0 0 S= 1 Sz= 1 , weight =  0.00437284260529177
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.004548987045935474
# state  py 0 -1 dyz 0 0 S= 1 Sz= 2 , weight =  0.017298993060569104
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.04046604986948501
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.01116021036041037
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.07637871139025997
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.14853159658805315
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.14278376932369297
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.007460786887534976
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.038942437913121124
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.04051109577773474
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.018606281588506232
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.0028511075705020704
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.15405653119220308
# state  dxy 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.008576558151026321
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.004543928845233488
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.016678598685610474
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.016033175715288877
# state  dxz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.00437284260529177
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.004548987045935472
# state  dyz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.01729899306056909
# state  dxy 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.00857655815102629
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.004543928845233492
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.016678598685610387
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.016033175715288887
# state  dxz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.00437284260529177
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.004548987045935463
# state  dyz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.017298993060569076
# eigenvalue =  -1.7425036578339268
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.010571961268456515
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.0186728089056225
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.02118208200065905
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.006852573214082736
# state  px -1 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.01301116136034395
# state  px -1 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.0034174177807105017
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.01057196126845652
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.018672808905622514
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.021182082000659044
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.006852573214082738
# state  py 0 -1 dyz 0 0 S= 1 Sz= 1 , weight =  0.01301116136034393
# state  py 0 -1 dyz 0 0 S= 1 Sz= 2 , weight =  0.0034174177807105074
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.09414881405028731
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.010942531432477783
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.003217279472935055
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.003527228712143635
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.0035531091060993576
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.1662910758760916
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.0038448202925316843
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.1886374579736938
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.061025728804324976
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.11587115960671217
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.03043388289060886
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.010571961268456519
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.018672808905622507
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.021182082000659075
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.006852573214082738
# state  dyz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.013011161360343923
# state  dyz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.0034174177807105065
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.01057196126845652
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.018672808905622486
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.021182082000659033
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.006852573214082734
# state  dyz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.013011161360343934
# state  dyz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.0034174177807105048
# eigenvalue =  -1.7425036578339244
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.0030166249204339364
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.009574779844205458
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.009177003457949409
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.0027265897831797994
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.00502619647579674
# state  px -1 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.023478734867733955
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.018399699560324532
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.0025145428737437018
# state  py 0 -1 dxy 0 0 S= 1 Sz= 0 , weight =  0.0030166249204339407
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.009574779844205452
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.009177003457949391
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.002726589783179805
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.00502619647579674
# state  py 0 -1 dxz 0 0 S= 1 Sz= 1 , weight =  0.023478734867733966
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.018399699560324518
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.0025145428737437005
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.08526839478822187
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0447608939688335
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.018840907654229022
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.026864613999372167
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.08172598916714216
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.024281700241745894
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.20909034634791152
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.16385889509970386
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.022393312218039776
# state  dxy 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.0030166249204339416
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.009574779844205468
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.009177003457949397
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.002726589783179805
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.00502619647579674
# state  dxz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.023478734867733966
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.018399699560324525
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.0025145428737437018
# state  dxy 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.0030166249204339407
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.009574779844205458
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.009177003457949404
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.002726589783179803
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.005026196475796732
# state  dxz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.02347873486773395
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.018399699560324518
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.002514542873743705
# eigenvalue =  -1.7425036578339235
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.003443793103834244
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.008022356540060987
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.007292823375175281
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.004474060737439242
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.0026635968094495415
# state  px -1 0 dyz 0 0 S= 0 Sz= 1 , weight =  0.00360637140696901
# state  px -1 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.04575932725635678
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.0034437931038342534
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.008022356540060966
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.007292823375175277
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.004474060737439242
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.002663596809449544
# state  py 0 -1 dyz 0 0 S= 0 Sz= 1 , weight =  0.003606371406969005
# state  py 0 -1 dyz 0 0 S= 1 Sz= 1 , weight =  0.04575932725635675
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.003165122705791606
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.06494638548285282
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.03211661321575855
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.030668768862022962
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.0714432577793183
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.0033098543059446876
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.039843838028017706
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.0237207150451863
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.40751061071130457
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.0034437931038342534
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.008022356540060992
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0072928233751752905
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.004474060737439238
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.00266359680944954
# state  dyz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0036063714069690133
# state  dyz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.04575932725635675
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.0034437931038342486
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.008022356540060982
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.007292823375175293
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.004474060737439249
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.002663596809449544
# state  dyz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.003606371406969004
# state  dyz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.04575932725635678
# eigenvalue =  -1.7425036578339212
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.003232787849435992
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.016285136980143392
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.013926980544064048
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.0236448191991524
# state  px -1 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.004292839248401222
# state  px -1 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.012712184476093269
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.0032327878494359964
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.01628513698014342
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.01392698054406409
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.02364481919915239
# state  py 0 -1 dyz 0 0 S= 1 Sz= 1 , weight =  0.004292839248401211
# state  py 0 -1 dyz 0 0 S= 1 Sz= 2 , weight =  0.012712184476093279
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0287896573182408
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.006118873806394542
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.1450276154436594
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.002729407534552604
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.1240270057966727
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.008290112833933775
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.21056941370715718
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.038229966406650134
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.11320861494107484
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0032327878494359916
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.016285136980143392
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.01392698054406409
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.02364481919915239
# state  dyz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.004292839248401222
# state  dyz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.012712184476093269
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.003232787849435989
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.016285136980143413
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.01392698054406404
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.023644819199152383
# state  dyz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.004292839248401215
# state  dyz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.012712184476093276
# eigenvalue =  -1.7425036578339193
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.02572156880084401
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.015056887795817493
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.019538709242231722
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.0035311051723101276
# state  px -1 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.01055006484248798
# state  py 0 -1 dxy 0 0 S= 1 Sz= 0 , weight =  0.025721568800844048
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.015056887795817497
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.01953870924223173
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.00353110517231013
# state  py 0 -1 dxz 0 0 S= 1 Sz= 1 , weight =  0.01055006484248798
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.13408941758934625
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.031446328246752205
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.009348680371091931
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.22906394912151315
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.17400236876748162
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.09395381498771677
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.0026052262959855737
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.0029381771474561967
# state  dxy 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.025721568800844054
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.015056887795817507
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.01953870924223173
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.003531105172310128
# state  dxz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.010550064842487992
# state  dxy 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.025721568800844002
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.0150568877958175
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.019538709242231722
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.003531105172310129
# state  dxz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.010550064842487975
# eigenvalue =  -1.7425036578339186
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.010226193420025046
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.0073325425913338274
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.007001092086542805
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.01683120884218074
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.016002323928938446
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.009667906319484183
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.010226193420025027
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.0073325425913338205
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.007001092086542805
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.01683120884218073
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.01600232392893841
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.009667906319484191
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.09106957151052544
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0185973124181972
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0048127305161746025
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.06530010576250338
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.062348366614957365
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.14989066941174872
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.018976096969551746
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.1425090181188347
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.08609773448986585
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.021692216783955283
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.020189953867732875
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.01022619342002503
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.007332542591333826
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.0070010920865428185
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.01683120884218074
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.016002323928938453
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.009667906319484193
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.010226193420025035
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.007332542591333818
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.007001092086542799
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.01683120884218074
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.016002323928938432
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.009667906319484186
# eigenvalue =  -1.7425036578339146
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.0029393349705566577
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.004790438574625508
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.004730931480447448
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.0031831152882178804
# state  px -1 0 dyz 0 0 S= 0 Sz= 1 , weight =  0.04941755069052466
# state  px -1 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.008545479886357869
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.002939334970556653
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.004790438574625504
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.004730931480447435
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.0031831152882178795
# state  py 0 -1 dyz 0 0 S= 0 Sz= 1 , weight =  0.049417550690524635
# state  py 0 -1 dyz 0 0 S= 1 Sz= 1 , weight =  0.008545479886357874
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.026176306793720183
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.04213140560458432
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.4400889931998517
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.007566572663479213
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.009882016577504748
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.0025089058348695594
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.042661347230568095
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.0032152047890454537
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.0029653516001333854
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.0283472973236503
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.07610194327817847
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0029393349705566464
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.004790438574625506
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.004730931480447427
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.0031831152882178795
# state  dyz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.04941755069052456
# state  dyz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.008545479886357869
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.00293933497055666
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.00479043857462551
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.004730931480447442
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.0031831152882178795
# state  dyz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.04941755069052461
# state  dyz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.008545479886357874
# eigenvalue =  -1.6847513043201199
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 px -1 0 S= 0 Sz= 1 , weight =  0.014048231581438102
# state  px -1 0 py 0 -1 S= 0 Sz= 1 , weight =  0.02858097038966449
# state  py 0 -1 py 0 -1 S= 0 Sz= 1 , weight =  0.014048231581438135
# state  py -2 -1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.009728717795006525
# state  py -2 1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.009728717795006529
# state  px -1 -2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.009728717795006505
# state  px -1 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.1393792217738402
# state  px -1 2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.009728717795006529
# state  py 0 -1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.13937922177384013
# state  dx2y2 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0721770544549305
# state  px -1 0 py 0 1 S= 0 Sz= 1 , weight =  0.028580970389664444
# state  py 0 -1 py 0 1 S= 0 Sz= 1 , weight =  0.02809646316287622
# state  dx2y2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.13937922177384005
# state  py 0 1 py 0 1 S= 0 Sz= 1 , weight =  0.014048231581438123
# state  dx2y2 0 0 px 1 -2 S= 0 Sz= 1 , weight =  0.009728717795006515
# state  px -1 0 px 1 0 S= 0 Sz= 1 , weight =  0.028096463162876194
# state  py 0 -1 px 1 0 S= 0 Sz= 1 , weight =  0.028580970389664433
# state  dx2y2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.13937922177384013
# state  py 0 1 px 1 0 S= 0 Sz= 1 , weight =  0.028580970389664413
# state  px 1 0 px 1 0 S= 0 Sz= 1 , weight =  0.014048231581438097
# state  dx2y2 0 0 px 1 2 S= 0 Sz= 1 , weight =  0.009728717795006525
# state  dx2y2 0 0 py 2 -1 S= 0 Sz= 1 , weight =  0.009728717795006506
# state  dx2y2 0 0 py 2 1 S= 0 Sz= 1 , weight =  0.009728717795006524
# eigenvalue =  -0.598744205175169
# Compute the weights in GS (lowest Aw peak)
# state  py -10 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025129018658376846
# state  py -10 1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025129018658376773
# state  px -9 -2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0028599057575050416
# state  px -9 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003041530864490976
# state  px -9 2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002859905757505043
# state  py -8 -3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0030714260247554433
# state  py -8 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0033826165524047107
# state  py -8 1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0033826165524047155
# state  py -8 3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003071426024755434
# state  px -7 -6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002508736387655792
# state  px -7 -4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003171756742457046
# state  px -7 -2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0035334966498134683
# state  px -7 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0036395382368635157
# state  px -7 2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0035334966498134644
# state  px -7 4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003171756742457038
# state  px -7 6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002508736387655774
# state  py -6 -7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025087363876557956
# state  py -6 -5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0032041302080110592
# state  py -6 -3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003547486431452503
# state  py -6 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003635911365149278
# state  py -6 1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003635911365149273
# state  py -6 3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003547486431452502
# state  py -6 5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003204130208011042
# state  py -6 7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002508736387655786
# state  px -5 -6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003204130208011066
# state  px -5 -4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003514513876393839
# state  px -5 -2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.00346469503047999
# state  px -5 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0033844378314839426
# state  px -5 2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003464695030479987
# state  px -5 4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0035145138763938186
# state  px -5 6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0032041302080110536
# state  py -4 -7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003171756742457046
# state  py -4 -5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003514513876393836
# state  py -4 -3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0032920174892156523
# state  py -4 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002912052521597917
# state  py -4 1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002912052521597922
# state  py -4 3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0032920174892156475
# state  py -4 5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0035145138763938407
# state  py -4 7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0031717567424570407
# state  px -3 -8 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003071426024755457
# state  px -3 -6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003547486431452509
# state  px -3 -4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0032920174892156558
# state  px -3 4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0032920174892156514
# state  px -3 6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.00354748643145251
# state  px -3 8 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003071426024755444
# state  py -2 -9 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0028599057575050494
# state  py -2 -7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0035334966498134727
# state  py -2 -5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0034646950304799895
# state  py -2 5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0034646950304799973
# state  py -2 7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0035334966498134627
# state  py -2 9 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002859905757505046
# state  px -1 -10 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025129018658376864
# state  px -1 -8 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0033826165524047077
# state  px -1 -6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0036359113651492823
# state  px -1 -4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002912052521597919
# state  px -1 4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002912052521597921
# state  px -1 6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003635911365149278
# state  px -1 8 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003382616552404714
# state  px -1 10 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025129018658376903
# state  py 0 -9 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003041530864490983
# state  py 0 -7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0036395382368635217
# state  py 0 -5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.003384437831483944
# state  dx2y2 0 0 py 0 5 S= 1 Sz= 2 , weight =  0.0033844378314839435
# state  dx2y2 0 0 py 0 7 S= 1 Sz= 2 , weight =  0.003639538236863524
# state  dx2y2 0 0 py 0 9 S= 1 Sz= 2 , weight =  0.003041530864490986
# state  dx2y2 0 0 px 1 -10 S= 1 Sz= 2 , weight =  0.002512901865837689
# state  dx2y2 0 0 px 1 -8 S= 1 Sz= 2 , weight =  0.003382616552404714
# state  dx2y2 0 0 px 1 -6 S= 1 Sz= 2 , weight =  0.0036359113651492753
# state  dx2y2 0 0 px 1 -4 S= 1 Sz= 2 , weight =  0.002912052521597915
# state  dx2y2 0 0 px 1 4 S= 1 Sz= 2 , weight =  0.002912052521597907
# state  dx2y2 0 0 px 1 6 S= 1 Sz= 2 , weight =  0.0036359113651492857
# state  dx2y2 0 0 px 1 8 S= 1 Sz= 2 , weight =  0.003382616552404714
# state  dx2y2 0 0 px 1 10 S= 1 Sz= 2 , weight =  0.002512901865837691
# state  dx2y2 0 0 py 2 -9 S= 1 Sz= 2 , weight =  0.002859905757505046
# state  dx2y2 0 0 py 2 -7 S= 1 Sz= 2 , weight =  0.00353349664981346
# state  dx2y2 0 0 py 2 -5 S= 1 Sz= 2 , weight =  0.0034646950304799756
# state  dx2y2 0 0 py 2 5 S= 1 Sz= 2 , weight =  0.003464695030479986
# state  dx2y2 0 0 py 2 7 S= 1 Sz= 2 , weight =  0.003533496649813481
# state  dx2y2 0 0 py 2 9 S= 1 Sz= 2 , weight =  0.002859905757505049
# state  dx2y2 0 0 px 3 -8 S= 1 Sz= 2 , weight =  0.003071426024755434
# state  dx2y2 0 0 px 3 -6 S= 1 Sz= 2 , weight =  0.003547486431452492
# state  dx2y2 0 0 px 3 -4 S= 1 Sz= 2 , weight =  0.00329201748921563
# state  dx2y2 0 0 px 3 4 S= 1 Sz= 2 , weight =  0.0032920174892156467
# state  dx2y2 0 0 px 3 6 S= 1 Sz= 2 , weight =  0.0035474864314524947
# state  dx2y2 0 0 px 3 8 S= 1 Sz= 2 , weight =  0.0030714260247554463
# state  dx2y2 0 0 py 4 -7 S= 1 Sz= 2 , weight =  0.003171756742457033
# state  dx2y2 0 0 py 4 -5 S= 1 Sz= 2 , weight =  0.003514513876393814
# state  dx2y2 0 0 py 4 -3 S= 1 Sz= 2 , weight =  0.003292017489215638
# state  dx2y2 0 0 py 4 -1 S= 1 Sz= 2 , weight =  0.0029120525215979107
# state  dx2y2 0 0 py 4 1 S= 1 Sz= 2 , weight =  0.002912052521597922
# state  dx2y2 0 0 py 4 3 S= 1 Sz= 2 , weight =  0.0032920174892156484
# state  dx2y2 0 0 py 4 5 S= 1 Sz= 2 , weight =  0.003514513876393826
# state  dx2y2 0 0 py 4 7 S= 1 Sz= 2 , weight =  0.003171756742457043
# state  dx2y2 0 0 px 5 -6 S= 1 Sz= 2 , weight =  0.003204130208011039
# state  dx2y2 0 0 px 5 -4 S= 1 Sz= 2 , weight =  0.003514513876393801
# state  dx2y2 0 0 px 5 -2 S= 1 Sz= 2 , weight =  0.0034646950304799942
# state  dx2y2 0 0 px 5 0 S= 1 Sz= 2 , weight =  0.00338443783148395
# state  dx2y2 0 0 px 5 2 S= 1 Sz= 2 , weight =  0.003464695030479995
# state  dx2y2 0 0 px 5 4 S= 1 Sz= 2 , weight =  0.003514513876393836
# state  dx2y2 0 0 px 5 6 S= 1 Sz= 2 , weight =  0.0032041302080110545
# state  dx2y2 0 0 py 6 -7 S= 1 Sz= 2 , weight =  0.0025087363876557687
# state  dx2y2 0 0 py 6 -5 S= 1 Sz= 2 , weight =  0.0032041302080110484
# state  dx2y2 0 0 py 6 -3 S= 1 Sz= 2 , weight =  0.0035474864314525
# ...
# eigenvalue =  -1.7425036578339206
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 0 Sz= 1 , weight =  0.006488891409141395
# state  px -1 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.017877019767479234
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.002710954369751739
# state  px -1 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.01642138997525606
# state  px -1 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.009956539567238031
# state  px -1 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.019881964109740254
# state  py 0 -1 dxy 0 0 S= 0 Sz= 1 , weight =  0.006488891409141411
# state  py 0 -1 dxy 0 0 S= 1 Sz= 1 , weight =  0.017877019767479234
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.002710954369751741
# state  py 0 -1 dxz 0 0 S= 1 Sz= 0 , weight =  0.01642138997525606
# state  py 0 -1 dyz 0 0 S= 1 Sz= 0 , weight =  0.009956539567238036
# state  py 0 -1 dyz 0 0 S= 1 Sz= 1 , weight =  0.019881964109740285
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.057786953163985015
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002858251871470073
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.0038242885055263564
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 1 , weight =  0.1592041596750426
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.02414245875248404
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.14624101923647634
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.005292163319388825
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 0 , weight =  0.08866816369230603
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.17705923190501
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.016369460354457684
# state  dxy 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.0064888914091414136
# state  dxy 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.017877019767479248
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.002710954369751738
# state  dxz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.016421389975256082
# state  dyz 0 0 py 0 1 S= 1 Sz= 0 , weight =  0.009956539567238047
# state  dyz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.019881964109740243
# state  dxy 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.006488891409141398
# state  dxy 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.017877019767479255
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.002710954369751738
# state  dxz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.01642138997525606
# state  dyz 0 0 px 1 0 S= 1 Sz= 0 , weight =  0.00995653956723804
# state  dyz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.019881964109740292
# eigenvalue =  -1.7425036578339201
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.017931358129690305
# state  px -1 0 dxz 0 0 S= 0 Sz= 1 , weight =  0.013785027113140818
# state  px -1 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.009398823587963236
# state  px -1 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.008135075336962193
# state  px -1 0 dyz 0 0 S= 0 Sz= 1 , weight =  0.005602886208071309
# state  px -1 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.009682142180780519
# state  px -1 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.008825553722063475
# state  py 0 -1 dxy 0 0 S= 1 Sz= 2 , weight =  0.017931358129690298
# state  py 0 -1 dxz 0 0 S= 0 Sz= 1 , weight =  0.013785027113140804
# state  py 0 -1 dxz 0 0 S= 1 Sz= 1 , weight =  0.009398823587963219
# state  py 0 -1 dxz 0 0 S= 1 Sz= 2 , weight =  0.008135075336962184
# state  py 0 -1 dyz 0 0 S= 0 Sz= 1 , weight =  0.005602886208071319
# state  py 0 -1 dyz 0 0 S= 1 Sz= 1 , weight =  0.009682142180780529
# state  py 0 -1 dyz 0 0 S= 1 Sz= 2 , weight =  0.008825553722063494
# state  dxy 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.01520044868579872
# state  dxz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.12276283665790848
# state  dyz 0 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.04989661599712234
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 0 , weight =  0.007230964101972994
# state  dx2y2 0 0 dxy 0 0 S= 1 Sz= 2 , weight =  0.1596880710543692
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 0 , weight =  0.005475256524759858
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 1 , weight =  0.0837014128035863
# state  dx2y2 0 0 dxz 0 0 S= 1 Sz= 2 , weight =  0.07244707729586221
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 1 , weight =  0.08622451223942457
# state  dx2y2 0 0 dyz 0 0 S= 1 Sz= 2 , weight =  0.07859614646419211
# state  dxy 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.01793135812969033
# state  dxz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.013785027113140804
# state  dxz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.009398823587963219
# state  dxz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.008135075336962198
# state  dyz 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.005602886208071324
# state  dyz 0 0 py 0 1 S= 1 Sz= 1 , weight =  0.009682142180780529
# state  dyz 0 0 py 0 1 S= 1 Sz= 2 , weight =  0.008825553722063497
# state  dxy 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.017931358129690305
# state  dxz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.013785027113140808
# state  dxz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.009398823587963236
# state  dxz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.008135075336962193
# state  dyz 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.005602886208071318
# state  dyz 0 0 px 1 0 S= 1 Sz= 1 , weight =  0.009682142180780529
# state  dyz 0 0 px 1 0 S= 1 Sz= 2 , weight =  0.00882555372206348
# eigenvalue =  -0.9043190673183658
# Compute the weights in GS (lowest Aw peak)
# state  px -1 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.03786248240915084
# state  py 0 -1 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.03786248240915096
# state  d3z2r2 0 0 d3z2r2 0 0 S= 0 Sz= 1 , weight =  0.8346052974250577
# state  d3z2r2 0 0 py 0 1 S= 0 Sz= 1 , weight =  0.037862482409150924
# state  d3z2r2 0 0 px 1 0 S= 0 Sz= 1 , weight =  0.037862482409150924
# eigenvalue =  -0.5987442051751679
# Compute the weights in GS (lowest Aw peak)
# state  px -7 -2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025712368118859393
# state  px -7 0 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0026484006128557995
# state  px -7 2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025712368118859163
# state  py -6 -3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025814168248038546
# state  py -6 -1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002645761429353497
# state  py -6 1 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0026457614293534824
# state  py -6 3 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025814168248038246
# state  px -5 -4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025574235241866655
# state  px -5 -2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025211716006009618
# state  px -5 2 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025211716006009457
# state  px -5 4 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025574235241866373
# state  py -4 -5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002557423524186657
# state  py -4 5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025574235241866317
# state  px -3 -6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002581416824803847
# state  px -3 6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.00258141682480383
# state  py -2 -7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002571236811885929
# state  py -2 -5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0025211716006009618
# state  py -2 5 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002521171600600957
# state  py -2 7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.002571236811885919
# state  px -1 -6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.00264576142935349
# state  px -1 6 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0026457614293534906
# state  py 0 -7 dx2y2 0 0 S= 1 Sz= 2 , weight =  0.0026484006128557904
# state  dx2y2 0 0 py 0 7 S= 1 Sz= 2 , weight =  0.0026484006128558004
# state  dx2y2 0 0 px 1 -6 S= 1 Sz= 2 , weight =  0.0026457614293534924
# state  dx2y2 0 0 px 1 6 S= 1 Sz= 2 , weight =  0.002645761429353495
# state  dx2y2 0 0 py 2 -7 S= 1 Sz= 2 , weight =  0.00257123681188593
# state  dx2y2 0 0 py 2 -5 S= 1 Sz= 2 , weight =  0.0025211716006009787
# state  dx2y2 0 0 py 2 5 S= 1 Sz= 2 , weight =  0.0025211716006009704
# state  dx2y2 0 0 py 2 7 S= 1 Sz= 2 , weight =  0.0025712368118859393
# state  dx2y2 0 0 px 3 -6 S= 1 Sz= 2 , weight =  0.0025814168248038585
# state  dx2y2 0 0 px 3 6 S= 1 Sz= 2 , weight =  0.0025814168248038624
# state  dx2y2 0 0 py 4 -5 S= 1 Sz= 2 , weight =  0.002557423524186675
# state  dx2y2 0 0 py 4 5 S= 1 Sz= 2 , weight =  0.0025574235241866633
# state  dx2y2 0 0 px 5 -4 S= 1 Sz= 2 , weight =  0.002557423524186671
# state  dx2y2 0 0 px 5 -2 S= 1 Sz= 2 , weight =  0.0025211716006009813
# state  dx2y2 0 0 px 5 2 S= 1 Sz= 2 , weight =  0.0025211716006009756
# state  dx2y2 0 0 px 5 4 S= 1 Sz= 2 , weight =  0.002557423524186661
# state  dx2y2 0 0 py 6 -3 S= 1 Sz= 2 , weight =  0.002581416824803875
# state  dx2y2 0 0 py 6 -1 S= 1 Sz= 2 , weight =  0.0026457614293535115
# state  dx2y2 0 0 py 6 1 S= 1 Sz= 2 , weight =  0.0026457614293535024
# state  dx2y2 0 0 py 6 3 S= 1 Sz= 2 , weight =  0.0025814168248038515
# state  dx2y2 0 0 px 7 -2 S= 1 Sz= 2 , weight =  0.002571236811885943
# state  dx2y2 0 0 px 7 0 S= 1 Sz= 2 , weight =  0.002648400612855804
# state  dx2y2 0 0 px 7 2 S= 1 Sz= 2 , weight =  0.002571236811885929
# eigenvalue =  -0.5987442051751676
# Compute the weights in GS (lowest Aw peak)
# eigenvalue =  -0.5987442051751647
# Compute the weights in GS (lowest Aw peak)
# state  py -8 -1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0026426846123666593
# state  py -8 1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.00264268461236668
# state  px -7 -2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002760491948162508
# state  px -7 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0028433103301495305
# state  px -7 2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002760491948162539
# state  py -6 -5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025031843526048558
# state  py -6 -3 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027712317647212827
# state  py -6 -1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002840089312735595
# state  py -6 1 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002840089312735615
# state  py -6 3 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.00277123176472134
# state  py -6 5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025031843526049204
# state  px -5 -6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025031843526048593
# state  px -5 -4 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027451560193115887
# state  px -5 -2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027051097186830226
# state  px -5 0 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0026417474040273557
# state  px -5 2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002705109718683063
# state  px -5 4 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002745156019311653
# state  px -5 6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025031843526049195
# state  py -4 -5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002745156019311597
# state  py -4 -3 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002567789983870552
# state  py -4 3 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025677899838706052
# state  py -4 5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002745156019311657
# state  px -3 -6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002771231764721287
# state  px -3 -4 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025677899838705584
# state  px -3 4 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002567789983870613
# state  px -3 6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027712317647213443
# state  py -2 -7 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027604919481625024
# state  py -2 -5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002705109718683037
# state  py -2 5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027051097186830773
# state  py -2 7 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002760491948162553
# state  px -1 -8 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0026426846123666628
# state  px -1 -6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002840089312735597
# state  px -1 6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0028400893127356304
# state  px -1 8 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0026426846123667
# state  py 0 -7 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0028433103301495283
# state  py 0 -5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0026417474040273553
# state  dx2y2 0 0 py 0 5 S= 0 Sz= 1 , weight =  0.002641747404027375
# state  dx2y2 0 0 py 0 7 S= 0 Sz= 1 , weight =  0.002843310330149546
# state  dx2y2 0 0 px 1 -8 S= 0 Sz= 1 , weight =  0.002642684612366675
# state  dx2y2 0 0 px 1 -6 S= 0 Sz= 1 , weight =  0.002840089312735622
# state  dx2y2 0 0 px 1 6 S= 0 Sz= 1 , weight =  0.0028400893127356183
# state  dx2y2 0 0 px 1 8 S= 0 Sz= 1 , weight =  0.0026426846123666784
# state  dx2y2 0 0 py 2 -7 S= 0 Sz= 1 , weight =  0.0027604919481625484
# state  dx2y2 0 0 py 2 -5 S= 0 Sz= 1 , weight =  0.0027051097186830716
# state  dx2y2 0 0 py 2 5 S= 0 Sz= 1 , weight =  0.0027051097186830586
# state  dx2y2 0 0 py 2 7 S= 0 Sz= 1 , weight =  0.002760491948162522
# state  dx2y2 0 0 px 3 -6 S= 0 Sz= 1 , weight =  0.0027712317647213373
# state  dx2y2 0 0 px 3 -4 S= 0 Sz= 1 , weight =  0.0025677899838706013
# state  dx2y2 0 0 px 3 4 S= 0 Sz= 1 , weight =  0.002567789983870577
# state  dx2y2 0 0 px 3 6 S= 0 Sz= 1 , weight =  0.0027712317647213104
# state  dx2y2 0 0 py 4 -5 S= 0 Sz= 1 , weight =  0.002745156019311647
# state  dx2y2 0 0 py 4 -3 S= 0 Sz= 1 , weight =  0.002567789983870605
# state  dx2y2 0 0 py 4 3 S= 0 Sz= 1 , weight =  0.0025677899838705788
# state  dx2y2 0 0 py 4 5 S= 0 Sz= 1 , weight =  0.002745156019311627
# state  dx2y2 0 0 px 5 -6 S= 0 Sz= 1 , weight =  0.0025031843526049204
# state  dx2y2 0 0 px 5 -4 S= 0 Sz= 1 , weight =  0.002745156019311652
# state  dx2y2 0 0 px 5 -2 S= 0 Sz= 1 , weight =  0.0027051097186830773
# state  dx2y2 0 0 px 5 0 S= 0 Sz= 1 , weight =  0.002641747404027383
# state  dx2y2 0 0 px 5 2 S= 0 Sz= 1 , weight =  0.002705109718683058
# state  dx2y2 0 0 px 5 4 S= 0 Sz= 1 , weight =  0.0027451560193116273
# state  dx2y2 0 0 px 5 6 S= 0 Sz= 1 , weight =  0.002503184352604884
# state  dx2y2 0 0 py 6 -5 S= 0 Sz= 1 , weight =  0.0025031843526049217
# state  dx2y2 0 0 py 6 -3 S= 0 Sz= 1 , weight =  0.0027712317647213425
# state  dx2y2 0 0 py 6 -1 S= 0 Sz= 1 , weight =  0.0028400893127356265
# state  dx2y2 0 0 py 6 1 S= 0 Sz= 1 , weight =  0.002840089312735618
# state  dx2y2 0 0 py 6 3 S= 0 Sz= 1 , weight =  0.002771231764721309
# state  dx2y2 0 0 py 6 5 S= 0 Sz= 1 , weight =  0.002503184352604886
# state  dx2y2 0 0 px 7 -2 S= 0 Sz= 1 , weight =  0.0027604919481625484
# state  dx2y2 0 0 px 7 0 S= 0 Sz= 1 , weight =  0.002843310330149542
# state  dx2y2 0 0 px 7 2 S= 0 Sz= 1 , weight =  0.0027604919481625293
# state  dx2y2 0 0 py 8 -1 S= 0 Sz= 1 , weight =  0.0026426846123666944
# state  dx2y2 0 0 py 8 1 S= 0 Sz= 1 , weight =  0.0026426846123666814
# eigenvalue =  -0.598744205175163
# Compute the weights in GS (lowest Aw peak)
# eigenvalue =  -0.5757880162474494
# Compute the weights in GS (lowest Aw peak)
# state  py -8 3 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002632115179483493
# state  px -7 2 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002532482969483358
# state  px -7 4 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0028448659011950962
# state  px -7 6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002551738905987826
# state  py -6 3 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027302202798635974
# state  py -6 5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002930927010755309
# state  py -6 7 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0025164964108239283
# state  px -5 4 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002805290000149636
# state  px -5 6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002885341818077237
# state  py -4 5 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027540621289100795
# state  py -4 7 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.0027151251809740275
# state  px -3 6 dx2y2 0 0 S= 0 Sz= 1 , weight =  0.002584419845127028
# state  dx2y2 0 0 px 3 -6 S= 0 Sz= 1 , weight =  0.0025844198451268445
# state  dx2y2 0 0 py 4 -7 S= 0 Sz= 1 , weight =  0.0027151251809738055
# state  dx2y2 0 0 py 4 -5 S= 0 Sz= 1 , weight =  0.002754062128909877
# state  dx2y2 0 0 px 5 -6 S= 0 Sz= 1 , weight =  0.002885341818076991
# state  dx2y2 0 0 px 5 -4 S= 0 Sz= 1 , weight =  0.002805290000149448
# state  dx2y2 0 0 py 6 -7 S= 0 Sz= 1 , weight =  0.0025164964108236876
# state  dx2y2 0 0 py 6 -5 S= 0 Sz= 1 , weight =  0.0029309270107550755
# state  dx2y2 0 0 py 6 -3 S= 0 Sz= 1 , weight =  0.0027302202798634204
# state  dx2y2 0 0 px 7 -6 S= 0 Sz= 1 , weight =  0.0025517389059875836
# state  dx2y2 0 0 px 7 -4 S= 0 Sz= 1 , weight =  0.0028448659011948855
# state  dx2y2 0 0 px 7 -2 S= 0 Sz= 1 , weight =  0.0025324829694832354
# state  dx2y2 0 0 py 8 -3 S= 0 Sz= 1 , weight =  0.0026321151794833314
# w_lowpeak =  -0.1795000000021174
# peak w-range = [ -0.21350000000209857 -0.147750000002135 ]
# peak, weight =  -0.1795000000021174    0.12019088256140159
# w_lowpeak =  -0.1795000000021174
# peak w-range = [ -0.21350000000209857 -0.147750000002135 ]
# peak, weight =  -0.1795000000021174    0.12019088256139775
# w_lowpeak =  -0.1795000000021174
# peak w-range = [ -0.21350000000209857 -0.147750000002135 ]
# peak, weight =  -0.1795000000021174    0.1201908825614035
